# %%
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor

# %%
print("All imports successful!")
print(f"Python version: {sys.version}")
print(f"Pandas version: {pd.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# All imports successful!
# Python version: 3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:11:29) [Clang 20.1.8 ]
# Pandas version: 2.3.3
# NumPy version: 2.3.5

# %%
# Test loading data
import os

data_path = "../data/raw/train_FD001.txt"

if os.path.exists(data_path):
    print("✅ Dataset found!")
    # Quick peek
    with open(data_path, 'r') as f:
        print("\nFirst 3 lines:")
        for i in range(3):
            print(f.readline().strip())
else:
    print("❌ Dataset NOT found - check data/raw/ folder")
# Out:
# ✅ Dataset found!
#
# First 3 lines:
# 1 1 -0.0007 -0.0004 100.0 518.67 641.82 1589.70 1400.60 14.62 21.61 554.36 2388.06 9046.19 1.30 47.47 521.66 2388.02 8138.62 8.4195 0.03 392 2388 100.00 39.06 23.4190
# 1 2 0.0019 -0.0003 100.0 518.67 642.15 1591.82 1403.14 14.62 21.61 553.75 2388.04 9044.07 1.30 47.49 522.28 2388.07 8131.49 8.4318 0.03 392 2388 100.00 39.00 23.4236
# 1 3 -0.0043 0.0003 100.0 518.67 642.35 1587.99 1404.20 14.62 21.61 554.26 2388.08 9052.94 1.30 47.27 522.42 2388.03 8133.23 8.4178 0.03 390 2388 100.00 38.95 23.3442

# %%
# Test notebook can access src modules (we'll add these later)
import sys
sys.path.append(os.path.abspath('..'))  # Go up one level from notebooks/ to project root

print("✅ Path configured for importing src modules")
print(f"Python path: {sys.path[0]}")
# Out:
# ✅ Path configured for importing src modules
# Python path: /opt/anaconda3/lib/python313.zip
